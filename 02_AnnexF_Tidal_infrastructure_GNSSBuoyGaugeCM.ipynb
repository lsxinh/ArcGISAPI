# %% [markdown]
# # Approaches to Newcastle

# %% [markdown]
# #### Import a shp file and visualise data using arcgis.mapping

# %%
#readin using sdf to test the table and geometry
import arcpy
import pandas as pd
from arcgis.mapping import show_styles, display_colormaps
from arcgis.gis import GIS
out_csv=r'E:\HIPP\11_Deliverables\06_Oceanography\01_DeployedEquipment\DeployedEquipment_UTM56S_SSDM.csv'
in_table = out_csv
out_feature_class = out_csv[:-3] + "shp"
print(out_feature_class)
arcpy.env.workspace = r"E:\HIPP\11_Deliverables\06_Oceanography\01_DeployedEquipment"
sdf_test = pd.DataFrame.spatial.from_featureclass(out_feature_class)
# sdf_test.spatial.plot()
sdf_test.spatial.plot(col='depth_m',renderer_type = 'c',class_count=5)
# Out:
# E:\HIPP\11_Deliverables\06_Oceanography\01_DeployedEquipment\DeployedEquipment_UTM56S_SSDM.shp
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-f4c7bd1b-8b73-4196-b47f-6d5f84515bea"><img src=""></img></div>
# <div class="map-html-embed-preview-f4c7bd1b-8b73-4196-b47f-6d5f84515bea"></div>

# %%
#view dataframe
sdf_test
# Out:
#     FID sampling_d  time_utc   date_lcl  time_lcl                sample_nam  \
# 0     0 2020-12-07  10:35:00 2020-12-07  21:35:00                       CM1
# 1     1 2020-12-09  02:47:00 2020-12-09  13:48:00                       CM2
# 2     2 2020-12-08  23:50:00 1900-01-01  11:00:00                GNSSBouy01
# 3     3 2020-12-22  13:48:00 1900-01-01  11:00:00                GNSSBouy02
# 4     4 2020-12-09  03:45:00 2020-12-10  14:45:00                GNSSBouy03
# 5     5 2020-12-27  02:02:00 2020-12-28  13:02:00                GNSSBouy04
# 6     6 2020-12-25  23:24:00 2020-12-26  10:24:00   NewcastlePort_TideGauge
# 7     7 2020-12-07  10:35:00 2020-12-07  21:35:00     TG1 - Telegraph Shoal
# 8     8 2020-12-08  22:38:00 2020-12-09  09:38:00    TG2 - Stockton Bight N
# 9     9 2020-12-09  03:38:00 2020-12-09  14:38:00     TG3 - Redhead Point E
# 10   10 2020-12-09  05:18:00 2020-12-09  16:18:00  TG4 - Redhead Point Deep
#
#           lat         lon       e_utm56s      n_utm56s  ...   days  \
# 0  -32.798333  152.113333  416981.995762  6.370722e+06  ...  38.84
# 1  -32.938333  151.843333  391870.890200  6.354956e+06  ...  78.69
# 2  -32.798333  152.113333  416981.995762  6.370722e+06  ...   8.84
# 3  -32.850000  152.145000  419993.353905  6.365018e+06  ...   3.44
# 4  -32.996667  151.780000  386024.865546  6.348422e+06  ...  13.90
# 5  -33.051667  151.856667  393253.964870  6.342404e+06  ...   5.87
# 6  -32.923833  151.789000  386772.847603  6.356506e+06  ...   8.97
# 7  -32.798333  152.113333  416981.995762  6.370722e+06  ...  38.84
# 8  -32.850000  152.145000  419993.353905  6.365018e+06  ...  37.27
# 9  -32.996667  151.780000  386024.865546  6.348422e+06  ...  78.65
# 10 -33.051667  151.856667  393253.964870  6.342404e+06  ...  36.86
#
#                                              data_url  \
# 0   11_FinalDeliverables\05_Tide\04_CurrentMeters\CM1
# 1   11_FinalDeliverables\05_Tide\04_CurrentMeters\CM2
# 2   11_FinalDeliverables\05_Tide\03_GNSS_TidalBuoy...
# 3   11_FinalDeliverables\05_Tide\03_GNSS_TidalBuoy...
# 4   11_FinalDeliverables\05_Tide\03_GNSS_TidalBuoy...
# 5   11_FinalDeliverables\05_Tide\03_GNSS_TidalBuoy...
# 6   11_FinalDeliverables\05_Tide\03_GNSS_TidalBuoy...
# 7   11_FinalDeliverables\05_Tide\02_SeabedMountedT...
# 8   11_FinalDeliverables\05_Tide\02_SeabedMountedT...
# 9   11_FinalDeliverables\05_Tide\02_SeabedMountedT...
# 10  11_FinalDeliverables\05_Tide\02_SeabedMountedT...
#
#                                               remarks  \
# 0
# 1
# 2                            at TG1 – Telegraph Shoal
# 3                             at TG2 Stockton Bight N
# 4                            at TG3 – Redhead Point E
# 5                           at TG4 Redhead Point Deep
# 6   Established permanent tide gauge serving port ...
# 7                                     15m water depth
# 8                                     95m water depth
# 9   33m water depth Equipment lost due to fishing ...
# 10                                    98m water depth
#
#                                     equipment_ penetrate  recovery report_url  \
# 0                                Current Meter       0.0       0.0
# 1                                Current Meter       0.0     100.0
# 2              GNSS Tide Bouy, Hemisphere S631       0.0     100.0
# 3              GNSS Tide Bouy, Hemisphere S631       0.0     100.0
# 4              GNSS Tide Bouy, Hemisphere S631       0.0     100.0
# 5              GNSS Tide Bouy, Hemisphere S631       0.0     100.0
# 6                           Vega Puls 62 Radar       0.0     100.0
# 7   Bottom Mounted Tide Gauge, Level TROLL 700       0.0     100.0
# 8   Bottom Mounted Tide Gauge, Level TROLL 700       0.0     100.0
# 9   Bottom Mounted Tide Gauge, Level TROLL 700       0.0     100.0
# 10  Bottom Mounted Tide Gauge, Level TROLL 700       0.0     100.0
#
#    sample_des                                            SHAPE_1  \
# 0              {'spatialReference': {'wkid': 32756}, 'x': 416...
# 1              {'spatialReference': {'wkid': 32756}, 'x': 391...
# 2              {'spatialReference': {'wkid': 32756}, 'x': 416...
# 3              {'spatialReference': {'wkid': 32756}, 'x': 419...
# 4              {'spatialReference': {'wkid': 32756}, 'x': 386...
# 5              {'spatialReference': {'wkid': 32756}, 'x': 393...
# 6              {'spatialReference': {'wkid': 32756}, 'x': 386...
# 7              {'spatialReference': {'wkid': 32756}, 'x': 416...
# 8              {'spatialReference': {'wkid': 32756}, 'x': 419...
# 9              {'spatialReference': {'wkid': 32756}, 'x': 386...
# 10             {'spatialReference': {'wkid': 32756}, 'x': 393...
#
#                                                 SHAPE
# 0   {"x": 416981.9957999997, "y": 6370721.5065, "s...
# 1   {"x": 391870.89020000026, "y": 6354955.8927, "...
# 2   {"x": 416981.9957999997, "y": 6370721.5065, "s...
# 3   {"x": 419993.35390000045, "y": 6365018.0441, "...
# 4   {"x": 386024.8655000003, "y": 6348421.7028, "s...
# 5   {"x": 393253.9649, "y": 6342404.3382, "spatial...
# 6   {"x": 386772.8476, "y": 6356506.4194, "spatial...
# 7   {"x": 416981.9957999997, "y": 6370721.5065, "s...
# 8   {"x": 419993.35390000045, "y": 6365018.0441, "...
# 9   {"x": 386024.8655000003, "y": 6348421.7028, "s...
# 10  {"x": 393253.9649, "y": 6342404.3382, "spatial...
#
# [11 rows x 25 columns]
