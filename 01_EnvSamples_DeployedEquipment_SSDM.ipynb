# %% [markdown]
# ### Step 1: Prepare a csv file using excel (note: formatting works better with old excel version)

# %% [markdown]
# ### Step 2: using XYTableToPoint to convert csv file into ESRI shp format

# %% [markdown]
# ### Step 3: Define field name and attribute values and use CalculateField to update field values

# %%
import arcpy
#define field names
ssdm_dict = dict()
ssdm_dict['LAST_UPDATE']='"22/02/2021"'
ssdm_dict['LAST_UPDATE_BY']='"XL"'
ssdm_dict['SURVEY_ID']='1001'
ssdm_dict['SURVEY_ID_REF']='"BN7875559"'
# ssdm_dict['SAMPLING_METHOD']='"IOGP1048 VELO-Velocity Meter"'
ssdm_dict['REPORT_URL']='"11_FinalDeliverables//1_SurveyReport_Document"'
ssdm_dict['APPROVED_DATE']='"2/03/2021"'
# ssdm_dict['SAMPLING_EQUIPMENT']='" "'
ssdm_dict['PENETRATION']='0'
ssdm_dict['RECOVERY']='100'
# ssdm_dict['SAMPLE_NUMBER']="!SAMPLE_NAME![3:]" #run 1 time only
# ssdm_dict['SYMBOLOGY_CODE']='"IOGP1046"'

#update fields
arcpy.env.workspace = r"E:\HIPP\11_Deliverables\SSDM\GIS\FGDB\HIPP_SI1001_UTM56S.gdb"
input_ft = r'Environmental_Samples\DeployedEquipment_Pnt'
for in_field in ssdm_dict.keys():
    new_value = ssdm_dict[in_field]
    print(in_field,new_value)
    try:
        arcpy.management.CalculateField(input_ft, in_field, new_value, "PYTHON3", '', "TEXT")
    except Exception as e:
        print(e)
# Out:
# LAST_UPDATE "22/02/2021"
# LAST_UPDATE_BY "XL"
# SURVEY_ID 1001
# SURVEY_ID_REF "BN7875559"
# REPORT_URL "11_FinalDeliverables//1_SurveyReport_Document"
# APPROVED_DATE "2/03/2021"
# PENETRATION 0
# RECOVERY 100

# %% [markdown]
# #### 3b Testing results

# %%
#readin using sdf to test the table and geometry
import pandas as pd
from arcgis.mapping import show_styles, display_colormaps
from arcgis.gis import GIS

arcpy.env.workspace = r"E:\HIPP\11_Deliverables\SSDM\GIS\FGDB\HIPP_SI1001_UTM56S.gdb"
input_ft = r'Environmental_Samples\DeployedEquipment_Pnt'

sdf_test = pd.DataFrame.spatial.from_featureclass(input_ft)
# sdf_test.spatial.plot()
sdf_test.spatial.plot(col='SAMPLE_NUMBER',renderer_type = 'c',class_count=5)
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-cce48eeb-c086-44ad-8e6e-f39db46a6f41"><img src=""></img></div>
# <div class="map-html-embed-preview-cce48eeb-c086-44ad-8e6e-f39db46a6f41"></div>

# %%
sdf_test
# Out:
#     OBJECTID LAST_UPDATE LAST_UPDATE_BY  \
# 0         23  2021-02-22             XL
# 1         24  2021-02-22             XL
# 2         25  2021-02-22             XL
# 3         26  2021-02-22             XL
# 4         27  2021-02-22             XL
# 5         28  2021-02-22             XL
# 6         29  2021-02-22             XL
# 7         30  2021-02-22             XL
# 8         31  2021-02-22             XL
# 9         32  2021-02-22             XL
# 10        33  2021-02-22             XL
#
#                                 FEATURE_ID  SURVEY_ID SURVEY_ID_REF  \
# 0   {FFB43F61-56B6-4234-BD88-E5D9A6A4AE06}       1001     BN7875559
# 1   {29A27E47-6116-47E2-8AAC-B753608EEC9E}       1001     BN7875559
# 2   {7F8AB98C-C9C6-46C3-A76E-9C9C9967BAC3}       1001     BN7875559
# 3   {C2B6F7B9-E884-445B-BF9F-0F7B3DBFCEBC}       1001     BN7875559
# 4   {AC198D3E-B01F-4C3E-9BA6-1B40AAC05CB9}       1001     BN7875559
# 5   {86BE85A1-465F-4E76-B65B-F09160A163B4}       1001     BN7875559
# 6   {6354A79D-B5A7-40B8-981C-E9079604DF75}       1001     BN7875559
# 7   {D5BF0B05-CF86-41B7-B86D-B701E90AE96B}       1001     BN7875559
# 8   {ED9AC513-3AA9-491C-B65A-8B1DA5BE71AE}       1001     BN7875559
# 9   {E0049988-D777-4B8E-8440-9ADC2FC689FD}       1001     BN7875559
# 10  {4CEFB032-AB85-49BB-9FE1-ECEC064A60D4}       1001     BN7875559
#
#                                               REMARKS  \
# 0
# 1
# 2                            at TG1 – Telegraph Shoal
# 3                             at TG2 Stockton Bight N
# 4                            at TG3 – Redhead Point E
# 5                           at TG4 Redhead Point Deep
# 6   Established permanent tide gauge serving port ...
# 7                                     15m water depth
# 8                                     95m water depth
# 9   33m water depth Equipment lost due to fishing ...
# 10                                    98m water depth
#
#                  SAMPLE_NAME SAMPLE_DESC SAMPLING_METHOD SAMPLING_DATE  \
# 0                        CM1                        None    2020-12-07
# 1                        CM2                        None    2020-12-09
# 2                 GNSSBouy01                        None    2020-12-08
# 3                 GNSSBouy02                        None    2020-12-22
# 4                 GNSSBouy03                        None    2020-12-09
# 5                 GNSSBouy04                        None    2020-12-27
# 6    NewcastlePort_TideGauge                        None    2020-12-25
# 7      TG1 - Telegraph Shoal                        None    2020-12-07
# 8     TG2 - Stockton Bight N                        None    2020-12-08
# 9      TG3 - Redhead Point E                        None    2020-12-09
# 10  TG4 - Redhead Point Deep                        None    2020-12-09
#
#                                              DATA_URL  \
# 0   11_FinalDeliverables\05_Tide\04_CurrentMeters\CM1
# 1   11_FinalDeliverables\05_Tide\04_CurrentMeters\CM2
# 2   11_FinalDeliverables\05_Tide\03_GNSS_TidalBuoy...
# 3   11_FinalDeliverables\05_Tide\03_GNSS_TidalBuoy...
# 4   11_FinalDeliverables\05_Tide\03_GNSS_TidalBuoy...
# 5   11_FinalDeliverables\05_Tide\03_GNSS_TidalBuoy...
# 6   11_FinalDeliverables\05_Tide\03_GNSS_TidalBuoy...
# 7   11_FinalDeliverables\05_Tide\02_SeabedMountedT...
# 8   11_FinalDeliverables\05_Tide\02_SeabedMountedT...
# 9   11_FinalDeliverables\05_Tide\02_SeabedMountedT...
# 10  11_FinalDeliverables\05_Tide\02_SeabedMountedT...
#
#                                        REPORT_URL  PENETRATION  RECOVERY  \
# 0   11_FinalDeliverables//1_SurveyReport_Document          0.0     100.0
# 1   11_FinalDeliverables//1_SurveyReport_Document          0.0     100.0
# 2   11_FinalDeliverables//1_SurveyReport_Document          0.0     100.0
# 3   11_FinalDeliverables//1_SurveyReport_Document          0.0     100.0
# 4   11_FinalDeliverables//1_SurveyReport_Document          0.0     100.0
# 5   11_FinalDeliverables//1_SurveyReport_Document          0.0     100.0
# 6   11_FinalDeliverables//1_SurveyReport_Document          0.0     100.0
# 7   11_FinalDeliverables//1_SurveyReport_Document          0.0     100.0
# 8   11_FinalDeliverables//1_SurveyReport_Document          0.0     100.0
# 9   11_FinalDeliverables//1_SurveyReport_Document          0.0     100.0
# 10  11_FinalDeliverables//1_SurveyReport_Document          0.0     100.0
#
#    APPROVED_DATE SAMPLE_NUMBER                          SAMPLING_EQUIPMENT  \
# 0     2021-03-02          None                               Current Meter
# 1     2021-03-02          None                               Current Meter
# 2     2021-03-02          None             GNSS Tide Bouy, Hemisphere S631
# 3     2021-03-02          None             GNSS Tide Bouy, Hemisphere S631
# 4     2021-03-02          None             GNSS Tide Bouy, Hemisphere S631
# 5     2021-03-02          None             GNSS Tide Bouy, Hemisphere S631
# 6     2021-03-02          None                          Vega Puls 62 Radar
# 7     2021-03-02          None  Bottom Mounted Tide Gauge, Level TROLL 700
# 8     2021-03-02          None  Bottom Mounted Tide Gauge, Level TROLL 700
# 9     2021-03-02          None  Bottom Mounted Tide Gauge, Level TROLL 700
# 10    2021-03-02          None  Bottom Mounted Tide Gauge, Level TROLL 700
#
#                                                 SHAPE
# 0   {"x": 416981.99580000003, "y": 6370721.5065000...
# 1   {"x": 391870.8902, "y": 6354955.892700001, "z"...
# 2   {"x": 416981.99580000003, "y": 6370721.5065000...
# 3   {"x": 419993.35390000005, "y": 6365018.0441000...
# 4   {"x": 386024.8655000001, "y": 6348421.70280000...
# 5   {"x": 393253.9649, "y": 6342404.338200001, "z"...
# 6   {"x": 386772.84760000004, "y": 6356506.4194000...
# 7   {"x": 416981.99580000003, "y": 6370721.5065000...
# 8   {"x": 419993.35390000005, "y": 6365018.0441000...
# 9   {"x": 386024.8655000001, "y": 6348421.70280000...
# 10  {"x": 393253.9649, "y": 6342404.338200001, "z"...
